# %% [markdown]
# Importing the dependencies

# %%
import numpy as np
import pandas as pd
import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
import csv

def read_csv_robust(filepath, encoding='utf-8', lineterminator='\n'):
    """Reads a CSV file line by line and handles potential parsing errors."""
    data = []
    with open(filepath, 'r', encoding=encoding, errors='ignore') as f:
        reader = csv.reader(f, lineterminator=lineterminator)
        for i, row in enumerate(reader):
            try:
                data.append(row)
            except Exception as e:
                print(f"Error reading row {i+1}: {e}")
                # Depending on the error and data, you might try to clean the row
                # or skip it: continue
    return data

# Try reading the files using the robust function
try:
    true_data = read_csv_robust('/content/True.csv', encoding='latin-1', lineterminator='\n')
    fake_data = read_csv_robust('/content/Fake.csv', encoding='latin-1', lineterminator='\n')

    # Convert the lists of rows back into DataFrames
    df_true = pd.DataFrame(true_data[1:], columns=true_data[0])
    df_fake = pd.DataFrame(fake_data[1:], columns=fake_data[0])

    print("Files read successfully.")
    display(df_true.head())
    display(df_fake.head())

except Exception as e:
    print(f"An error occurred during the robust reading process: {e}")
# Out:
# Files read successfully.
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Yearâ...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obamaâs Na...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
df_true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
df_fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Yearâ...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obamaâs Na...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %% [markdown]
# Both true and Fake data set have missing output column

# %%
df_true['lable'] = 1
df_fake['lable'] = 0

# %%
df_true
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text       subject  \
# 0      WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1      WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2      WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3      WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4      SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
# ...                                                  ...           ...
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...     worldnews
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...     worldnews
# 21414  MINSK (Reuters) - In the shadow of disused Sov...     worldnews
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...     worldnews
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...     worldnews
#
#                      date  lable
# 0      December 31, 2017       1
# 1      December 29, 2017       1
# 2      December 31, 2017       1
# 3      December 30, 2017       1
# 4      December 29, 2017       1
# ...                   ...    ...
# 21412    August 22, 2017       1
# 21413    August 22, 2017       1
# 21414    August 22, 2017       1
# 21415    August 22, 2017       1
# 21416    August 22, 2017       1
#
# [21417 rows x 5 columns]

# %% [markdown]
# Combining both the data set together

# %%
df_combined = pd.concat([df_true, df_fake], axis=0, ignore_index=True)

# %%
df_combined
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 44893  McPain: John McCain Furious That Iran Treated ...
# 44894  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 44895  Sunnistan: US and Allied âSafe Zoneâ Plan ...
# 44896  How to Blow $700 Million: Al Jazeera America F...
# 44897  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text       subject  \
# 0      WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1      WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2      WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3      WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4      SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
# ...                                                  ...           ...
# 44893  21st Century Wire says As 21WIRE reported earl...   Middle-east
# 44894  21st Century Wire says It s a familiar theme. ...   Middle-east
# 44895  Patrick Henningsen  21st Century WireRemember ...   Middle-east
# 44896  21st Century Wire says Al Jazeera America will...   Middle-east
# 44897  21st Century Wire says As 21WIRE predicted in ...   Middle-east
#
#                      date  lable
# 0      December 31, 2017       1
# 1      December 29, 2017       1
# 2      December 31, 2017       1
# 3      December 30, 2017       1
# 4      December 29, 2017       1
# ...                   ...    ...
# 44893    January 16, 2016      0
# 44894    January 16, 2016      0
# 44895    January 15, 2016      0
# 44896    January 14, 2016      0
# 44897    January 12, 2016      0
#
# [44898 rows x 5 columns]

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
print(stopwords.words('english'))
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she'd", "she'll", "she's", 'should', 'shouldn', "shouldn't", "should've", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', "they'd", "they'll", "they're", "they've", 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', "we'd", "we'll", "we're", 'were', 'weren', "weren't", "we've", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", 'your', "you're", 'yours', 'yourself', 'yourselves', "you've"]

# %% [markdown]
# **Data Preprocessing**

# %%
df_combined.shape
# Out:
# (44898, 5)

# %%
df_combined.sample(5)
# Out:
#                                                    title  \
# 1642   Republicans plan healthcare vote; Obama and TV...
# 40102  FBI DIRECTOR CONFIRMS Hillaryâs Worst Nightm...
# 11281  Israel ambassador asks to meet New Zealand pop...
# 1580   New Jersey mayor resigns after admitting corru...
# 35628  WHY PICTURE OF CHE-OBAMA Was Much Worse Than A...
#
#                                                     text       subject  \
# 1642   WASHINGTON (Reuters) - Senate Republicans anno...  politicsNews
# 40102  Be careful what you ask for Watch:  FBI Direct...     left-news
# 11281  WELLINGTON (Reuters) - Israel s ambassador to ...     worldnews
# 1580   NEW YORK (Reuters) - The mayor of Paterson, Ne...  politicsNews
# 35628  Oh the irony, of our Nobel-Peace-Prize-Recipie...      politics
#
#                       date  lable
# 1642   September 20, 2017       1
# 40102          May 5, 2017      0
# 11281   December 27, 2017       1
# 1580   September 25, 2017       1
# 35628         Mar 25, 2016      0

# %%
#counting the number of missing values in the dataset

df_combined.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# lable      0
# dtype: int64

# %%
#replacing the null value by empty strings

news_dataset = df_combined.fillna('')

# %%
news_dataset = news_dataset.sample(frac=1, random_state=100).reset_index(drop=True)

# %%
news_dataset.head(10)
# Out:
#                                                title  \
# 0  China, Pakistan to look at including Afghanist...
# 1  10 REASONS A VOTE RECOUNT Is A Really Bad Idea...
# 2  DEBBIE WASSERMAN SCHULTZ Planned To Continue P...
# 3   FINALLY: Sheriff Joe Ruled In Contempt Over R...
# 4  Obama says he does not think FBI's Comey is tr...
# 5  TRUMP WAS RIGHT! Why The Heck Is This Liberal ...
# 6  LATE NIGHT HOST Goes Low In Anti-Trump Rant Wi...
# 7  South Korea's Moon asks Russia to continue sup...
# 8  YOUâLL NEVER BELIEVE WHICH REPUBLICAN JUST C...
# 9  Alabama Senate election winner due to be certi...
#
#                                                 text       subject  \
# 0  BEIJING (Reuters) - China and Pakistan will lo...     worldnews
# 1  Watch Jill Stein explain why she s working to ...     left-news
# 2  Democratic Rep. Debbie Wasserman Schultz seemi...      politics
# 3  A Maricopa Country judge has finally stood up ...          News
# 4  WASHINGTON (Reuters) - President Barack Obama ...  politicsNews
# 5  If you watch CNBC at all you know John Harwood...      politics
# 6  COLBERT   LANGUAGE WARNING! This late night ho...      politics
# 7  VLADIVOSTOK, Russia (Reuters) - South Korean P...     worldnews
# 8  What kind of leader speaks like this? It s obv...      politics
# 9  WASHINGTON (Reuters) - The outcome of Alabamaâ...  politicsNews
#
#                  date  lable
# 0  December 26, 2017       1
# 1        Nov 27, 2016      0
# 2        Jul 29, 2017      0
# 3        May 14, 2016      0
# 4   November 5, 2016       1
# 5        Oct 28, 2015      0
# 6         May 2, 2017      0
# 7  September 7, 2017       1
# 8        Aug 27, 2015      0
# 9  November 18, 2017       1

# %%
X = news_dataset.drop(columns = ['subject', 'date', 'lable'], axis= 1)
Y = news_dataset['lable']

# %%
print(X)
print(Y)
# Out:
#                                                    title  \
# 0      China, Pakistan to look at including Afghanist...
# 1      10 REASONS A VOTE RECOUNT Is A Really Bad Idea...
# 2      DEBBIE WASSERMAN SCHULTZ Planned To Continue P...
# 3       FINALLY: Sheriff Joe Ruled In Contempt Over R...
# 4      Obama says he does not think FBI's Comey is tr...
# ...                                                  ...
# 44893  Hungary's Jobbik supports EU deepening with vo...
# 44894  Trump aides hope win on taxes will stem slide ...
# 44895  South Africa's Zuma says influence-peddling in...
# 44896  Iran's Rouhani says foreign interference in Sy...
# 44897  GOVERNMENT GONE WILD: NY Man Return From Hospi...
#
#                                                     text
# 0      BEIJING (Reuters) - China and Pakistan will lo...
# 1      Watch Jill Stein explain why she s working to ...
# 2      Democratic Rep. Debbie Wasserman Schultz seemi...
# 3      A Maricopa Country judge has finally stood up ...
# 4      WASHINGTON (Reuters) - President Barack Obama ...
# ...                                                  ...
# 44893  BUDAPEST (Reuters) - Hungary s main opposition...
# 44894  WASHINGTON (Reuters) - Near the end of Preside...
# 44895  JOHANNESBURG (Reuters) - South African Preside...
# 44896  SOCHI, Russia (Reuters) - Iranian President Ha...
# 44897  Can you imagine? This man goes for a knee repl...
#
# [44898 rows x 2 columns]
# 0        1
# 1        0
# 2        0
# 3        0
# 4        1
#         ..
# 44893    1
# 44894    1
# 44895    1
# 44896    1
# 44897    0
# Name: lable, Length: 44898, dtype: int64

# %% [markdown]
# Stemming
# i.e-- reducing words to its Root word

# %%
port_stem = PorterStemmer()

def stemming(content):
    stemmed_content = re.sub('[^a-zA-Z]',' ', content)
    stemmed_content = stemmed_content.lower()
    stemmed_content = stemmed_content.split()
    stemmed_content = [port_stem.stem(word) for word in stemmed_content if not word in stopwords.words('english')]
    stemmed_content = ' '.join(stemmed_content)
    return stemmed_content

# %%
news_dataset['content'] = news_dataset['title'] + ' ' + news_dataset['text']
news_dataset['content'] = news_dataset['content'].apply(stemming)

# %%
print(news_dataset['content'])
# Out:
# 0        china pakistan look includ afghanistan billion...
# 1        reason vote recount realli bad idea america wa...
# 2        debbi wasserman schultz plan continu pay musli...
# 3        final sheriff joe rule contempt racial profil ...
# 4        obama say think fbi comey tri influenc elect w...
#                                ...
# 44893    hungari jobbik support eu deepen voter bless b...
# 44894    trump aid hope win tax stem slide poll number ...
# 44895    south africa zuma say influenc peddl govern in...
# 44896    iran rouhani say foreign interfer syria must e...
# 44897    govern gone wild ny man return hospit find hom...
# Name: content, Length: 44898, dtype: object

# %%
#seperating the data and the lables

X = news_dataset['content'].values
Y = news_dataset['lable'].values

# %%
print(X)
# Out:
# ['china pakistan look includ afghanistan billion econom corridor beij reuter china pakistan look extend billion china pakistan econom corridor afghanistan chines foreign minist wang yi said tuesday part china ambiti belt road plan link china asia europ beyond china tri posit help parti promot talk pakistan afghanistan uneasi neighbor ever sinc pakistan independ tie poison recent year afghan accus pakistan support taliban insurg fight u back kabul order limit influenc old rival india afghanistan pakistan deni say want see peac stabl afghanistan speak first trilater meet foreign minist china pakistan afghanistan wang said china hope econom corridor could benefit whole region act impetu develop afghanistan urgent need develop improv peopl live hope join inter connect initi wang told report announc pakistan afghanistan agre mend strain relat china pakistan will look afghanistan basi win win mutual benefici principl use appropri mean extend china pakistan econom corridor afghanistan ad could happen need three countri reach gradual consensu tackl easier smaller project first wang said without give detail pakistani foreign minist khawaja asif said countri china iron brother directli mention prospect afghanistan join corridor success implement cpec china pakistan econom corridor project serv model enhanc connect cooper similar project neighbor countri includ afghanistan iran central west asia said india look askanc project part run pakistan administ kashmir india consid territori though wang said plan noth territori disput china sought bring kabul islamabad togeth partli due chines fear spread islamist milit pakistan afghanistan unrest prone far western chines region xinjiang china push pakistan afghanistan improv tie better tackl violenc respect countri also tri broker peac talk afghan taliban milit limit effect tent talk process collaps wang said china fulli support peac talk afghan govern taliban would continu provid necessari facilit belt road infrastructur drive aim build modern day silk road connect china economi southeast central asia land middl east europ sea'
#  'reason vote recount realli bad idea america watch jill stein explain work forc recount state use democrat stronghold http youtu ajxjj r uyua ms stein start answer cnn interview video would anyon want count vote sure count accur know lot hack take place around elect much equip use open hack basic invit hack malfeas tamper human error etc reason horribl idea vote count integr real expert believ recount need describ detroit free press report say scientist believ identifi question trend clinton perform wors wisconsin counti reli electron vote machin compar paper ballot optic scanner clear report michigan pennsylvania reportedli cite scientist chri thoma longtim director michigan bureau elect said michigan use electron vote machin identifi report sourc potenti hack entir paper optic scan state thoma told free presswednesday noth connect internet zero proof actual hack malwar illeg tamper vote state exampl given report hypothet possibl discuss well elect known equip limit elect took place stein word let clear evid fraud stein say smoke gun elect surround hack polit real motiv recount truli elect integr improv public confid process includ recount new hampshir nevada state clinton narrow margin new hampshir clinton vote smallest margin victori state nevada hillari clinton margin victori vote far less trump margin victori pennsylvania threshold recount like reach pennsylvania would need evid widespread voter fraud court order recount pa exampl candid actual file vote recount pennsylvania law instead would challeng counti board regard vote comput state appeal judg would rule statewid recount necessari mean clinton campaign case ms stein team
ket six month arrest dull airport attempt leav associ press report awan lawyer chri gowen said awan inform hous plan visit famili wasserman schultz spokesman cite awan monday arrest reason end employ tuesday upon learn arrest termin offic insist termin prompt monday arrest hous sergeant arm ban wife touch congression comput six month pakistan suggest board flight without incid would still payrol awan wife hina left countri similar circumst march withdraw coupl three kid school without tell virginia educ offici pack possess hide cash accord fbi affidavit allegedli hundr thousand dollar wait pakistan money fbi say awan obtain partli mortgag fraud wire oversea use fals explan two day later march hous record show hina cut wasserman schultz payrol though hina bought round trip ticket return six month fbi said believ alvi intent return unit state wasserman schultz spokesman david darmrom respond dcnf ig request explain hina termin two day trip claim temporari husband termin six month move part time natur work ban absenc unlik notic two day without someon tell offic plan wasserman schultz offic also answer offic knew hina round trip perman move hina awan aid whose job requir access network hous sergeant arm ban access begin feb awan hina staffer payrol record latest avail period march indic staffer vendor ad payrol ban hous sourc said awan seen hous offic build multipl time network ban imran awan work advisori role wasserman schultz spok ...
#  ...
#  'south africa zuma say influenc peddl govern investig johannesburg reuter south african presid jacob zuma said saturday alleg privat busi wield undu influenc govern investig judici commiss inquiri countri high court rule wednesday zuma must set judici inquiri state influenc peddl within day uphold find graft watchdog report entitl state captur report focus alleg zuma friend businessmen brother ajay atul rajesh gupta influenc appoint minist zuma gupta deni accus wrongdo zuma speak saturday start weekend confer african nation congress vote new parti leader'
#  'iran rouhani say foreign interfer syria must end name name sochi russia reuter iranian presid hassan rouhani said wednesday foreign interfer conflict syria must end foreign militari presenc countri may accept invit syria govern rouhani stop short name specif nation also told russian counterpart vladimir putin turkey tayyip erdogan need uproot last terrorist cell syria ground prepar polit settlement rouhani speak three leader meet southern russian citi sochi'
#  'govern gone wild ny man return hospit find home demolish citi imagin man goe knee replac return home find citi demolish hous talk big brother long island town hall order demolit local resid hous recuper knee surgeri florida philip william head florida last decemb escap winter undergo oper time return home august home west hempstead long island raze ground remain empti lot cover grass speak cb news mr william said expect leav get surgeri come back find everyth gone outrag abl prevent unjust tremend disservic neighbor complain local town offici hous built poor condit properli maintain town sent number regist letter william claim never saw florida recov surgeri instruct local lawyer bradley siegel sue town compens town claim wrote william octob novemb went florida knee replac surgeri insist never read notic town spokeswoman susan trenkl pokalski said hempstead town follow proper procedur regard properti owner notif relat proceed structur pose danger public taken accord law william deni abandon hous said contain late wife jewelri person possess well tree parent plant everyth remov site follow demolit said want explan town knock home person belong social media user condemn hempstead town action one claim made major mistak even bother look lien foreclosur civil case pend hard investig statu owner hey hempstead guarante man nice payout instead hempstead move harbor town soon enough read daili mail']

# %%
#converting textual data to the numerical data

vectorizer = TfidfVectorizer()
vectorizer.fit(X)

X = vectorizer.transform(X)

# %% [markdown]
# **Train Test Split**

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, stratify=Y, random_state=2)

# %% [markdown]
# **Training the model**

# %%
model = LogisticRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# **Evaluation**
#
#
#
# Accuracy Score

# %%
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy score of the training data : ', training_data_accuracy)
# Out:
# Accuracy score of the training data :  0.9917311654323737

# %%
#accuracy score on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy score of the test data : ', test_data_accuracy)
# Out:
# Accuracy score of the test data :  0.9861915367483296

# %% [markdown]
# **Making a predictive system**

# %%
X_new = X_test[3]

prediction = model.predict(X_new)
print(prediction)

if (prediction[0]==0):
  print('The news is Fake')
else:
  print('The news is True')
# Out:
# [0]
# The news is Fake

# %%
print(Y_test[3])
# Out:
# 0
